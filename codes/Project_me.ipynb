# %%
import pandas as pd
import numpy as np

stm=pd.read_csv(r"D:\Cybrom\Python\Project Me\steam_c.csv")

# %%
stm
# Out:
#     web-scraper-order                  web-scraper-start-url  \
# 0        1712850596-1  https://vginsights.com/games-database
# 1        1712850598-2  https://vginsights.com/games-database
# 2        1712850600-3  https://vginsights.com/games-database
# 3        1712850603-4  https://vginsights.com/games-database
# 4        1712850605-5  https://vginsights.com/games-database
# ..                ...                                    ...
# 255    1712851245-256  https://vginsights.com/games-database
# 256    1712851248-257  https://vginsights.com/games-database
# 257    1712851250-258  https://vginsights.com/games-database
# 258    1712851253-259  https://vginsights.com/games-database
# 259    1712851255-260  https://vginsights.com/games-database
#
#                     title                           title-href   Price  \
# 0            Just Survive   https://vginsights.com/game/295110   $0.00
# 1              Planet Zoo   https://vginsights.com/game/703080  $11.24
# ...

# %%
stm.head()
# Out:
#   web-scraper-order                  web-scraper-start-url  \
# 0      1712850596-1  https://vginsights.com/games-database
# 1      1712850598-2  https://vginsights.com/games-database
# 2      1712850600-3  https://vginsights.com/games-database
# 3      1712850603-4  https://vginsights.com/games-database
# 4      1712850605-5  https://vginsights.com/games-database
#
#                   title                           title-href   Price  \
# 0          Just Survive   https://vginsights.com/game/295110   $0.00
# 1            Planet Zoo   https://vginsights.com/game/703080  $11.24
# 2  Dyson Sphere Program  https://vginsights.com/game/1366540  $19.99
# 3          Black Desert   https://vginsights.com/game/582660   $9.99
# 4              黑色沙漠(失效)  https://vginsights.com/game/1258320   $0.00
#
#                                               Geners             Developers  \
# 0                     Genres: MMO, Action, Adventure  Daybreak Game Company
# ...

# %%
stm.tail()
# Out:
#     web-scraper-order                  web-scraper-start-url  \
# 255    1712851245-256  https://vginsights.com/games-database
# 256    1712851248-257  https://vginsights.com/games-database
# 257    1712851250-258  https://vginsights.com/games-database
# 258    1712851253-259  https://vginsights.com/games-database
# 259    1712851255-260  https://vginsights.com/games-database
#
#                    title                          title-href  Price  \
# 255             Terraria  https://vginsights.com/game/105600  $4.99
# 256   Grand Theft Auto V  https://vginsights.com/game/271590  $0.00
# 257               Dota 2     https://vginsights.com/game/570  $0.00
# 258  PUBG: BATTLEGROUNDS  https://vginsights.com/game/578080    NaN
# 259     Counter-Strike 2     https://vginsights.com/game/730  $0.00
#
#                                      Geners      Developers      Publishers  \
# 255   Genres: Adventure, Indie, RPG, Action        Re-Logic        Re-Logic
# ...

# %%
stm.describe()
# Out:
#        web-scraper-order                  web-scraper-start-url         title  \
# count                260                                    260           260
# unique               260                                      1           260
# top         1712850596-1  https://vginsights.com/games-database  Just Survive
# freq                   1                                    260             1
#
#                                 title-href  Price          Geners Developers  \
# count                                  260    200             260        259
# unique                                 260     23             145        183
# top     https://vginsights.com/game/295110  $0.00  Genres: Action      Valve
# freq                                     1     43              32         12
#
#        Publishers                First Release Date  \
# count         255                               260
# unique        142                               244
# ...

# %%
stm.describe().columns
# Out:
# Index(['web-scraper-order', 'web-scraper-start-url', 'title', 'title-href',
#        'Price', 'Geners', 'Developers', 'Publishers', 'First Release Date',
#        'Average Prise last 6 months', 'Steam Link', 'Active Player (4-11-24)',
#        'Positive Reviews', 'Gross Revenue', 'Units Sold', 'Average Play Time'],
#       dtype='object')

# %%
stm.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   web-scraper-order            260 non-null    object
#  1   web-scraper-start-url        260 non-null    object
#  2   title                        260 non-null    object
#  3   title-href                   260 non-null    object
#  4   Price                        200 non-null    object
#  5   Geners                       260 non-null    object
#  6   Developers                   259 non-null    object
#  7   Publishers                   255 non-null    object
#  8   First Release Date           260 non-null    object
#  9   Average Prise last 6 months  260 non-null    object
#  10  Steam Link                   260 non-null    object
#  11  Active Player (4-11-24)      260 non-null    object
#  12  Positive Reviews             260 non-null    object
# ...

# %%
stm.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   web-scraper-order            260 non-null    object
#  1   web-scraper-start-url        260 non-null    object
#  2   title                        260 non-null    object
#  3   title-href                   260 non-null    object
#  4   Price                        200 non-null    object
#  5   Geners                       260 non-null    object
#  6   Developers                   259 non-null    object
#  7   Publishers                   255 non-null    object
#  8   First Release Date           260 non-null    object
#  9   Average Prise last 6 months  260 non-null    object
#  10  Steam Link                   260 non-null    object
#  11  Active Player (4-11-24)      260 non-null    object
#  12  Positive Reviews             260 non-null    object
# ...

# %%
stm.info(verbose=True,show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 16 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   web-scraper-order            260 non-null    object
#  1   web-scraper-start-url        260 non-null    object
#  2   title                        260 non-null    object
#  3   title-href                   260 non-null    object
#  4   Price                        200 non-null    object
#  5   Geners                       260 non-null    object
#  6   Developers                   259 non-null    object
#  7   Publishers                   255 non-null    object
#  8   First Release Date           260 non-null    object
#  9   Average Prise last 6 months  260 non-null    object
#  10  Steam Link                   260 non-null    object
#  11  Active Player (4-11-24)      260 non-null    object
#  12  Positive Reviews             260 non-null    object
# ...
